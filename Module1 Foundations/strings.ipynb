# %%
# text data 
# strings examples 

"Invoice_123.pdf"
"SUCCESS"
"FAILED"
"john@example.com"
"2026-06-11"

# real world examples 
# Cleaning document ids
# Extracting IDS
# Parsing the log file
# Processing csv data
# cleaning customer name
# validatting the addresses.
# Out:
# '2026-06-11'

# %%
# creating a strins
name = "subbu"

# %%
# indexing 
name[0]
# Out:
# 'subb'

# %%
# slicing 
name[:3]
# Out:
# 'sub'

# %%
# looping system
for char in name:
    print(char)
# Out:
# s
# u
# b
# b
# u

# %%
# Common methods
print(name.upper())
print(name.lower())
print(name.strip())
print(name.replace("Subbu","sub"))
print(name.split())
print(name.startswith("S"))
print(name.endswith("u"))
# Out:
# SUBBU
# subbu
# subbu
# subbu
# ['subbu']
# False
# True

# %%
# example : 
file_name = "invoice_123.pdf"
file_name.endswith(".pdf")
# Out:
# True

# %%
# string searching

log = "ERROR occured in while transforming the data"
if "ERROR" in log:
    print(log)
# Out:
# ERROR occured in while transforming the data

# %%
# String Splitting
record = "John,50000,Bangalore"

record.split(",")  # this basically how csv parsing works.
# Out:
# ['John', '50000', 'Bangalore']
